# %% [markdown]
# # Pipeline: Synchronous EDTech + Data Enlargement + Q-Learning

# %%
import pandas as pd, numpy as np
print('This notebook contains a synchronous pipeline that generated a large synthetic dataset, trained models, and ran a tabular Q-learning agent.')

# %%
print('Saved files in /mnt/data: students_large.csv and items.csv')

# %%
import json
results = {"Logistic": {"accuracy": 0.55808, "f1": 0.7131879543094496}, "RandomForest": {"accuracy": 0.6232, "f1": 0.6819286871961103}, "MLP": {"accuracy": 0.56424, "f1": 0.6951021550517772}}
print('Model results:\n', results)

# %%
import numpy as np
Q_shape = [25, 5]
print('Q-table shape:', Q_shape)
print('Top actions per state (0..):', [0, 0, 0, 4, 0, 4, 4, 4, 4, 0, 4, 4, 4, 4, 4, 3, 4, 4, 4, 0, 0, 0, 0, 0, 0])

# %%
# Load saved enlarged dataset and items
import pandas as pd
students = pd.read_csv('/mnt/data/students_large.csv')
items = pd.read_csv('/mnt/data/items.csv')
students.head()
